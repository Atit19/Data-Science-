# %% [markdown]
# <a href="https://colab.research.google.com/github/Atit19/R.Descriptive/blob/main/Anova_Table_Penguin_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load libraries
from sklearn import datasets
# Load digits dataset
iris = datasets.load_iris()

# %%
df=pd.read_csv('https://raw.githubusercontent.com/slmsshk/DataSet/main/penguins.csv')
df=df.dropna()
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
import scipy.stats as stats
stats.f_oneway(df.iloc[:,2], df.iloc[:,3],df.iloc[:,4],df.iloc[:,5])
# Out:
# F_onewayResult(statistic=8727.000884974641, pvalue=0.0)
