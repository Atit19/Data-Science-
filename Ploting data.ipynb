# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("F:\Data Science Assignments\Assignment No 2\Data Q1.csv")

# %%
df
# Out:
#      Name of company Measure X
# 0      Allied Signal    24.23%
# 1      Bankers Trust    25.53%
# 2      General Mills    25.41%
# 3     ITT Industries    24.14%
# 4   J.P.Morgan & Co.    29.62%
# 5    Lehman Brothers    28.25%
# 6           Marriott    25.81%
# 7                MCI    24.39%
# 8      Merrill Lynch    40.26%
# 9          Microsoft    32.95%
# 10    Morgan Stanley    91.36%
# 11  Sun Microsystems    25.99%
# 12         Travelers    39.42%
# 13        US Airways    26.71%
# 14    Warner-Lambert    35.00%

# %% [markdown]
# # Ploting a above data using pie chart

# %%
df=pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])
df_name=['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers',
      'Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways',
      'Warner-Lambert']

# %%
plt.figure(figsize=(6,8))
plt.pie(df,labels=df_name,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # Calculating Mean,variance & Standard deviation

# %%
df.mean()
# Out:
# 33.27133333333333

# %%
df.var()
# Out:
# 287.1466123809524

# %%
df.std()
# Out:
# 16.945400921222028

# %%
df.median()
# Out:
# 26.71

# %%
df.mode()
# Out:
# 0     24.14
# 1     24.23
# 2     24.39
# 3     25.41
# 4     25.53
# 5     25.81
# 6     25.99
# 7     26.71
# 8     28.25
# 9     29.62
# 10    32.95
# 11    35.00
# 12    39.42
# 13    40.26
# 14    91.36
# dtype: float64

# %% [markdown]
# # ploting a box plot for finding outlier

# %%
sns.boxplot(df,linewidth=1,width=1)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>
